# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_excel('/Users/maryramirez/Ironhack/week_9/Mid-bootcamp-project_4/data/clean/BBDD_cake.xlsx', sheet_name='BBDD')
display(data1.head())
print(data1.shape)
# Out:
#   Distrito Nombre_proDucto Diametro  Inch  Piezas  relleno_cobertura Tipo_R_C  \
# 0        A   Victoria Cake    18 cm   7.0      15                  1      NaN
# 1        A   Victoria Cake    18 cm   7.0      15                  1       GN
# 2        A   Victoria Cake    18 cm   7.0      15                  1       GN
# 3        A   Victoria Cake    18 cm   7.0      15                  1       GN
# 4        A   Victoria Cake    18 cm   7.0      15                  1       GN
#
#    FonDant TipoFonDant  Temática Tipo_Tematica Distantcia     Precio
# 0        1    FonDantM         1        Básica          A  34.332074
# 1        1    FonDantM         1        Básica          B  42.332074
# 2        1    FonDantM         1        Básica          C  50.332074
# 3        1    FonDantM         1        Básica          D  26.332074
# 4        1    FonDantM         1         MeDia          A  36.332074
# (3520, 13)

# %%
data1.columns
# Out:
# Index(['Distrito', 'Nombre_proDucto', 'Diametro', 'Inch', 'Piezas',
#        'relleno_cobertura', 'Tipo_R_C', 'FonDant', 'TipoFonDant', 'Temática',
#        'Tipo_Tematica', 'Distantcia', 'Precio'],
#       dtype='object')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3520 entries, 0 to 3519
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Distrito           3520 non-null   object
#  1   Nombre_proDucto    3520 non-null   object
#  2   Diametro           3520 non-null   object
#  3   Inch               3520 non-null   float64
#  4   Piezas             3520 non-null   int64
#  5   relleno_cobertura  3520 non-null   int64
#  6   Tipo_R_C           3519 non-null   object
#  7   FonDant            3520 non-null   int64
#  8   TipoFonDant        3520 non-null   object
#  9   Temática           3520 non-null   int64
#  10  Tipo_Tematica      3520 non-null   object
#  11  Distantcia         3520 non-null   object
#  12  Precio             3520 non-null   float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 357.6+ KB

# %%
#lower columns name.
cols = []
for i in range(len(data1.columns)):
    cols.append(data1.columns[i].lower())
data1.columns = cols

data1.head()
# Out:
#   distrito nombre_producto diametro  inch  piezas  relleno_cobertura tipo_r_c  \
# 0        A   Victoria Cake    18 cm   7.0      15                  1      NaN
# 1        A   Victoria Cake    18 cm   7.0      15                  1       GN
# 2        A   Victoria Cake    18 cm   7.0      15                  1       GN
# 3        A   Victoria Cake    18 cm   7.0      15                  1       GN
# 4        A   Victoria Cake    18 cm   7.0      15                  1       GN
#
#    fondant tipofondant  temática tipo_tematica distantcia     precio
# 0        1    FonDantM         1        Básica          A  34.332074
# 1        1    FonDantM         1        Básica          B  42.332074
# 2        1    FonDantM         1        Básica          C  50.332074
# 3        1    FonDantM         1        Básica          D  26.332074
# 4        1    FonDantM         1         MeDia          A  36.332074

# %%
# renaming columns
data1 = data1.rename(columns={'distrito':'location',
                            'nombre_producto':'product_name', 
                            'diametro':'diameter',
                            'piezas':'piece',
                            'relleno_cobertura':'cover_fill',
                            'tipo_r_c':'type_r_c',
                            'tipofondant':'fondant_type',
                             'temática':'topic',
                             'tipo_tematica':'topic_type',
                             'distantcia':'distance',
                             'precio':'price'})
data1.head()
# Out:
#   location   product_name diameter  inch  piece  cover_fill type_r_c  fondant  \
# 0        A  Victoria Cake    18 cm   7.0     15           1      NaN        1
# 1        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 2        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 3        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 4        A  Victoria Cake    18 cm   7.0     15           1       GN        1
#
#   fondant_type  topic topic_type distance      price
# 0     FonDantM      1     Básica        A  34.332074
# 1     FonDantM      1     Básica        B  42.332074
# 2     FonDantM      1     Básica        C  50.332074
# 3     FonDantM      1     Básica        D  26.332074
# 4     FonDantM      1      MeDia        A  36.332074

# %%
data1['product_name'].value_counts(dropna=False)

# %%
data1['diameter'].value_counts(dropna=False)

# %%
data1['cover_fill'].value_counts(dropna=False)

# %%
data1['type_r_c'].value_counts(dropna=False)
# Out:
# BC       400
# GCL      360
# DL       360
# GN       359
# MerNZ    320
# LimC     320
# GB       280
# BCO      280
# MerF     280
# MerFR    280
# MerM     280
# NaN        1
# Name: type_r_c, dtype: int64

# %%
data1['type_r_c'] = data1['type_r_c'].fillna('GN')
data1.head()
# Out:
#   location   product_name diameter  inch  piece  cover_fill type_r_c  fondant  \
# 0        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 1        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 2        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 3        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 4        A  Victoria Cake    18 cm   7.0     15           1       GN        1
#
#   fondant_type  topic topic_type distance      price
# 0     FonDantM      1     Básica        A  34.332074
# 1     FonDantM      1     Básica        B  42.332074
# 2     FonDantM      1     Básica        C  50.332074
# 3     FonDantM      1     Básica        D  26.332074
# 4     FonDantM      1      MeDia        A  36.332074

# %%
data1['fondant_type'].value_counts(dropna=False)

# %%
data1['topic_type'].value_counts(dropna=False)
# Out:
# Básica          704
# MeDia           704
# Alta            704
# Muy Alta        704
# Sin Tematica    704
# Name: topic_type, dtype: int64

# %%
data1['distance'].value_counts(dropna=False)
# Out:
# A    880
# B    880
# C    880
# D    880
# Name: distance, dtype: int64

# %%
data1 = data1.round({"price":2})
data1.head()
# Out:
#   location   product_name diameter  inch  piece  cover_fill type_r_c  fondant  \
# 0        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 1        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 2        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 3        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 4        A  Victoria Cake    18 cm   7.0     15           1       GN        1
#
#   fondant_type  topic topic_type distance  price
# 0     FonDantM      1     Básica        A  34.33
# 1     FonDantM      1     Básica        B  42.33
# 2     FonDantM      1     Básica        C  50.33
# 3     FonDantM      1     Básica        D  26.33
# 4     FonDantM      1      MeDia        A  36.33

# %%
df = data1.copy()

# %%
df = df[df['distance']=='D']
df.head()
# Out:
#    location   product_name diameter  inch  piece  cover_fill type_r_c  \
# 3         A  Victoria Cake    18 cm   7.0     15           1       GN
# 7         A  Victoria Cake    18 cm   7.0     15           1       GN
# 11        A  Victoria Cake    18 cm   7.0     15           1       GN
# 15        A  Victoria Cake    18 cm   7.0     15           1       GN
# 19        A  Victoria Cake    18 cm   7.0     15           1       GN
#
#     fondant fondant_type  topic    topic_type distance  price
# 3         1     FonDantM      1        Básica        D  26.33
# 7         1     FonDantM      1         MeDia        D  28.33
# 11        1     FonDantM      1          Alta        D  31.33
# 15        1     FonDantM      1      Muy Alta        D  35.33
# 19        1     FonDantM      0  Sin Tematica        D  23.33

# %%
df = df.reset_index(drop= True)
df.head()
# Out:
#   location   product_name diameter  inch  piece  cover_fill type_r_c  fondant  \
# 0        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 1        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 2        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 3        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 4        A  Victoria Cake    18 cm   7.0     15           1       GN        1
#
#   fondant_type  topic    topic_type distance  price
# 0     FonDantM      1        Básica        D  26.33
# 1     FonDantM      1         MeDia        D  28.33
# 2     FonDantM      1          Alta        D  31.33
# 3     FonDantM      1      Muy Alta        D  35.33
# 4     FonDantM      0  Sin Tematica        D  23.33

# %%
df.shape
# Out:
# (880, 13)

# %%
cakeDesign= pd.read_excel('/Users/maryramirez/Ironhack/week_9/Mid-bootcamp-project_4/data/clean/BBDD_cake.xlsx', sheet_name='BBDD cake designs')
display(cakeDesign.head())
print(cakeDesign.shape)
# Out:
#   Distrito Nombre_producto Diametro  Inch  Piezas  relleno_cobertura Tipo_R_C  \
# 0        B   Victoria Cake    12 cm  4.11       9                  1       GC
# 1        B   Victoria Cake    12 cm  4.11       9                  1      GCB
# 2        B   Victoria Cake    12 cm  4.11       9                  1       DL
# 3        B   Victoria Cake    12 cm  4.11       9                  1      GCL
# 4        B   Chocolat Cake    12 cm  4.11       9                  1       GC
#
#    Fondant  TipoFondant  Temática Tipo_Tematica Distantcia  Precio
# 0        0            0         1        Básica          D      39
# 1        0            0         1        Básica          D      39
# 2        0            0         1        Básica          D      39
# 3        0            0         1        Básica          D      39
# 4        0            0         1        Básica          D      39
# (28, 13)

# %%
# renaming columns
cakeDesign = cakeDesign.rename(columns={'Distrito':'location',
                            'Nombre_producto':'product_name', 
                            'Diametro':'diameter',
                            'Inch':'inch',
                            'Piezas':'piece',
                            'relleno_cobertura':'cover_fill',
                            'Tipo_R_C':'type_r_c',
                              'Fondant':'fondant',
                            'TipoFondant':'fondant_type',
                             'Temática':'topic',
                             'Tipo_Tematica':'topic_type',
                             'Distantcia':'distance',
                             'Precio':'price'})
cakeDesign.head()
# Out:
#   location   product_name diameter  inch  piece  cover_fill type_r_c  fondant  \
# 0        B  Victoria Cake    12 cm  4.11      9           1       GC        0
# 1        B  Victoria Cake    12 cm  4.11      9           1      GCB        0
# 2        B  Victoria Cake    12 cm  4.11      9           1       DL        0
# 3        B  Victoria Cake    12 cm  4.11      9           1      GCL        0
# 4        B  Chocolat Cake    12 cm  4.11      9           1       GC        0
#
#    fondant_type  topic topic_type distance  price
# 0             0      1     Básica        D     39
# 1             0      1     Básica        D     39
# 2             0      1     Básica        D     39
# 3             0      1     Básica        D     39
# 4             0      1     Básica        D     39

# %%
sweet = pd.read_excel('/Users/maryramirez/Ironhack/week_9/Mid-bootcamp-project_4/data/clean/BBDD_cake.xlsx', sheet_name='BBDD sweet36')
display(sweet.head())
print(sweet.shape)
# Out:
#   Distrito Nombre_producto Diametro  Inch  Piezas  relleno_cobertura Tipo_R_C  \
# 0        C   Chocolat Cake    12 cm  4.11       9                  1       GC
# 1        C   Victoria Cake    12 cm  4.11       9                  1       GC
# 2        C      Red Velvet    12 cm  4.11       9                  1       BC
# 3        C     Carrot Cake    12 cm  4.11       9                  1       BC
# 4        C   Chocolat Cake    18 cm  7.00      15                  1       GC
#
#    Fondant  TipoFondant  Temática Tipo_Tematica Distantcia  Precio
# 0        0            0         1        Basica          D      45
# 1        0            0         1        Basica          D      45
# 2        0            0         1        Basica          D      45
# 3        0            0         1        Basica          D      45
# 4        0            0         1        Basica          D      60
# (48, 13)

# %%
# renaming columns
sweet = sweet.rename(columns={'Distrito':'location',
                            'Nombre_producto':'product_name', 
                            'Diametro':'diameter',
                            'Inch':'inch',
                            'Piezas':'piece',
                            'relleno_cobertura':'cover_fill',
                            'Tipo_R_C':'type_r_c',
                              'Fondant':'fondant',
                            'TipoFondant':'fondant_type',
                             'Temática':'topic',
                             'Tipo_Tematica':'topic_type',
                             'Distantcia':'distance',
                             'Precio':'price'})
sweet.head()
# Out:
#   location   product_name diameter  inch  piece  cover_fill type_r_c  fondant  \
# 0        C  Chocolat Cake    12 cm  4.11      9           1       GC        0
# 1        C  Victoria Cake    12 cm  4.11      9           1       GC        0
# 2        C     Red Velvet    12 cm  4.11      9           1       BC        0
# 3        C    Carrot Cake    12 cm  4.11      9           1       BC        0
# 4        C  Chocolat Cake    18 cm  7.00     15           1       GC        0
#
#    fondant_type  topic topic_type distance  price
# 0             0      1     Basica        D     45
# 1             0      1     Basica        D     45
# 2             0      1     Basica        D     45
# 3             0      1     Basica        D     45
# 4             0      1     Basica        D     60

# %%
cakes = pd.concat([df,cakeDesign,sweet],axis = 0)

# %%
cakes.head()
# Out:
#   location   product_name diameter  inch  piece  cover_fill type_r_c  fondant  \
# 0        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 1        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 2        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 3        A  Victoria Cake    18 cm   7.0     15           1       GN        1
# 4        A  Victoria Cake    18 cm   7.0     15           1       GN        1
#
#   fondant_type  topic    topic_type distance  price
# 0     FonDantM      1        Básica        D  26.33
# 1     FonDantM      1         MeDia        D  28.33
# 2     FonDantM      1          Alta        D  31.33
# 3     FonDantM      1      Muy Alta        D  35.33
# 4     FonDantM      0  Sin Tematica        D  23.33

# %%
cakes.shape
# Out:
# (956, 13)

# %%
cakes = cakes.reset_index(drop= True)

# %%
cakes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   location      956 non-null    object
#  1   product_name  956 non-null    object
#  2   diameter      956 non-null    object
#  3   inch          956 non-null    float64
#  4   piece         956 non-null    int64
#  5   cover_fill    956 non-null    int64
#  6   type_r_c      956 non-null    object
#  7   fondant       956 non-null    int64
#  8   fondant_type  956 non-null    object
#  9   topic         956 non-null    int64
#  10  topic_type    956 non-null    object
#  11  distance      956 non-null    object
#  12  price         956 non-null    float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 97.2+ KB

# %%
cakes.nunique()
# Out:
# location          3
# product_name     10
# diameter         10
# inch              3
# piece             3
# cover_fill        1
# type_r_c         13
# fondant           2
# fondant_type      4
# topic             2
# topic_type        8
# distance          1
# price           564
# dtype: int64

# %%
# Eliminar caracteres 'cm' de la variable diameter
cakes['diameter'] = cakes['diameter'].apply(lambda x: x.replace("cm",""))
cakes.head()
# Out:
#   location   product_name diameter  inch  piece  cover_fill type_r_c  fondant  \
# 0        A  Victoria Cake      18    7.0     15           1       GN        1
# 1        A  Victoria Cake      18    7.0     15           1       GN        1
# 2        A  Victoria Cake      18    7.0     15           1       GN        1
# 3        A  Victoria Cake      18    7.0     15           1       GN        1
# 4        A  Victoria Cake      18    7.0     15           1       GN        1
#
#   fondant_type  topic    topic_type distance  price
# 0     FonDantM      1        Básica        D  26.33
# 1     FonDantM      1         MeDia        D  28.33
# 2     FonDantM      1          Alta        D  31.33
# 3     FonDantM      1      Muy Alta        D  35.33
# 4     FonDantM      0  Sin Tematica        D  23.33

# %%
# cambiar formato diameter en float 
cakes['diameter']=cakes['diameter'].astype(float)

# %%
cakes.describe().T
# Out:
#             count       mean        std    min    25%    50%      75%   max
# diameter    956.0  18.156904   3.540412  12.00  18.00  18.00  18.0000  32.0
# inch        956.0   7.009372   1.565934   4.11   7.00   7.00   7.0000  10.0
# piece       956.0  16.248954   5.927551   9.00  15.00  15.00  15.0000  30.0
# cover_fill  956.0   1.000000   0.000000   1.00   1.00   1.00   1.0000   1.0
# fondant     956.0   0.460251   0.498678   0.00   0.00   0.00   1.0000   1.0
# topic       956.0   0.803347   0.397676   0.00   1.00   1.00   1.0000   1.0
# price       956.0  42.464017  17.134835   9.67  30.43  38.35  52.3225  95.0

# %%
# matriz correlation

#plt.figure(figsize=(6,5))
#sns.heatmap(cakes.corr(), annot= True)
#plt.show()
